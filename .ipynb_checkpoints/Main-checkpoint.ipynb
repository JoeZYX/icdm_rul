# %%
from models.Exp import Exp_TStransformer
import torch
import torch.nn as nn
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__
    
    
args = dotdict()
# training setting 
args.train_epochs           = 150
args.learning_rate_patience = 15
args.learning_rate_factor   = 0.3
args.learning_rate          = 0.0001
args.use_gpu                = True if torch.cuda.is_available() else False
args.gpu                    = 0
args.optimizer              = "Adam"
args.criterion              = "WeightMSE"
args.batch_size             =  48
args.early_stop_patience    = 60



# model parameters
args.flag                   = "train"
args.late                   = False

args.attention_layer_types  = ["LocalSymmetry","LocLogSymmetry","ProbMask"]
args.d_model                = 8*5*len(args.attention_layer_types)

args.embedd_kernel_size     = 3
args.forward_kernel_size    = 1
args.value_kernel_size      = 1
args.causal_kernel_size     = 3
args.d_ff                   = None
args.n_heads                = 5*len(args.attention_layer_types)
args.e_layers               = 4
args.dropout                = 0.1
args.norm                   = "batch"
args.se_block               = False
args.activation             = "relu"
args.output_attention       = True
args.factor                 = 5  # 直接被输入了 目前没有被用到

# loading data


args.data_path              = "CMAPSSData/"
args.Data_id                = "FD001"
args.sequence_length        = 40
args.MAXLIFE                = 120
args.difference             = True
args.diff_periods           = 30
args.normalization          = "znorm"
args.validation             = 0.1
# Out:
# c:\users\joezh\appdata\local\programs\python\python36\lib\site-packages\numpy\core\__init__.py:29: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\joezh\appdata\local\programs\python\python36\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# c:\users\joezh\appdata\local\programs\python\python36\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
exp = Exp_TStransformer(args)
# Out:
# Use GPU: cuda:0
# load the data  CMAPSSData/   FD001
# ['setting3', 's1', 's5', 's10', 's16', 's18', 's19', 'setting3_diff', 's1_diff', 's5_diff', 's10_diff', 's16_diff', 's18_diff', 's19_diff', 'setting1', 'setting2', 'setting1_diff', 'setting2_diff', 's3_diff', 's6_diff', 's17_diff']
# train : the shape of data_X is :  (14870, 40, 27)
# load the data  CMAPSSData/   FD001
# ['setting3', 's1', 's5', 's10', 's16', 's18', 's19', 'setting3_diff', 's1_diff', 's5_diff', 's10_diff', 's16_diff', 's18_diff', 's19_diff', 'setting1', 'setting2', 'setting1_diff', 'setting2_diff', 's3_diff', 's6_diff', 's17_diff']
# val : the shape of data_X is :  (1861, 40, 27)
# build not late
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c3142f58fc9d> in <module>
# ----> 1 exp = Exp_TStransformer(args)
#
# F:\ICDM\gitversion\icdm_rul\models\Exp.py in __init__(self, args)
#     148
#     149
# --> 150         self.model = self._build_model().to(self.device)
#     151
#     152         self.optimizer_dict = {"Adam":optim.Adam}
#
# F:\ICDM\gitversion\icdm_rul\models\Exp.py in _build_model(self)
#     186                                   se_block              = self.args.se_block,
#     187                                   activation            = self.args.activation,
# --> 188                                   output_attention      = self.args.output_attention)
#     189         else:
#     190             raise NotImplementedError("late transformer")
#
# F:\ICDM\gitversion\icdm_rul\models\model.py in __init__(self, enc_in, input_length, c_out, d_model, attention_layer_types, embedd_kernel_size, forward_kernel_size, value_kernel_size, causal_kernel_size, d_ff, n_heads, e_layers, dropout, norm, se_block, activation, output_attention)
#      90         # self.decoder = ??????????????
#      91
# ---> 92         self.predictor = FullPredictor(d_model, input_length)
#      93         #self.donwconv1 = nn.Conv1d(in_channels = d_model,
#      94         #                           out_channels = int(d_model/2),
#
# F:\ICDM\gitversion\icdm_rul\models\Predictor.py in __init__(self, d_model, input_length)
#      11         self.donwconv1 = nn.Conv1d(in_channels = d_model,
#      12                                    out_channels = int(d_model/2),
# ---> 13                                    kernel_size  = 3).double()
#      14         self.activation1 = F.relu
#      15         self.norm1       = nn.BatchNorm1d(int(d_model/2))
#
# c:\users\joezh\appdata\local\programs\python\python36\lib\site-packages\torch\nn\modules\module.py in __setattr__(self, name, value)
#     609                 if modules is None:
#     610                     raise AttributeError(
# --> 611                         "cannot assign module before Module.__init__() call")
#     612                 remove_from(self.__dict__, self._parameters, self._buffers)
#     613                 modules[name] = value
#
# AttributeError: cannot assign module before Module.__init__() call

# %%
sum_ = 0
for p in exp.model.parameters():
    temp_sum = 1
    for s in p.shape:
        temp_sum = temp_sum*s
    sum_ = sum_ + temp_sum
sum_
# Out:
# 687923

# %%
save_path = "fd004"
exp.train(save_path)
# Out:
# train_steps:  966
# test_steps:  109
# start training
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8cd5fb1bcfa1> in <module>()
#       1 save_path = "fd004"
# ----> 2 exp.train(save_path)
#
# F:\ICDM\ICDM2021\models\Exp.py in train(self, save_path)
#     279                 # model prediction
#     280                 if self.args.output_attention:
# --> 281                     outputs = self.model(batch_x)[0]
#     282                 else:
#     283                     outputs = self.model(batch_x)
#
# D:\Anaconda\envs\icdm\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# F:\ICDM\ICDM2021\models\model.py in forward(self, x)
#     121
#     122         enc_out = self.enc_embedding(x)
# --> 123         enc_out, attns = self.encoder(enc_out)
#     124         #print(enc_out.shape)
#     125         paddding_enc_out  = nn.functional.pad(enc_out.permute(0, 2, 1),
#
# D:\Anaconda\envs\icdm\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# F:\ICDM\ICDM2021\models\Encoder.py in forward(self, x)
#     219
#     220         for encoder_layer in self.encoder_layers:
# --> 221             x, attn = encoder_layer(x)
#     222             attns.append(attn)
#     223
#
# D:\Anaconda\envs\icdm\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# F:\ICDM\ICDM2021\models\Encoder.py in forward(self, x)
#     198                                             pad=(forward_padding_size, forward_padding_size),
#     199                                             mode='replicate')
# --> 200             y = self.dropout(self.activation2(self.conv2(y)))
#     201
#     202             y = self.norm2(x+y).permute(0, 2, 1)  # B L  C
#
# D:\Anaconda\envs\icdm\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# D:\Anaconda\envs\icdm\lib\site-packages\torch\nn\modules\dropout.py in forward(self, input)
#      56
#      57     def forward(self, input: Tensor) -> Tensor:
# ---> 58         return F.dropout(input, self.p, self.training, self.inplace)
#      59
#      60
#
# D:\Anaconda\envs\icdm\lib\site-packages\torch\nn\functional.py in dropout(input, p, training, inplace)
#     981     return (_VF.dropout_(input, p, training)
#     982             if inplace
# --> 983             else _VF.dropout(input, p, training))
#     984
#     985
#
# KeyboardInterrupt:

# %% [markdown]
# # 结果training上的

# %%
best_model_path = "logs/time/108.67780056597796_checkpoint.pth"
exp.model.load_state_dict(torch.load(best_model_path))
# Out:
# <All keys matched successfully>

# %%
for i in exp.vali_loader:
    input_x = i[0].double().to(exp.device)
    gt_y    = i[1].double().to(exp.device)
    break

# %%
for i in exp.train_loader:
    input_x = i[0].double().to(exp.device)
    gt_y    = i[1].double().to(exp.device)
    break

# %%
exp.model.eval()

prediction_y = exp.model(input_x)[0]

# %%
gt_y = gt_y.detach().cpu()
prediction_y = prediction_y.detach().cpu()

import matplotlib.pyplot as plt
for i in range(gt_y.shape[0]):
    plt.figure(figsize=(8,4))
    plt.plot(gt_y[i])
    plt.plot(prediction_y[i])
# Out:
# D:\Anaconda\envs\icdm\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# # test

# %%
args.flag   = "test"
args.batch_size = 1
test_exp = Exp_TStransformer(args)
best_model_path = "logs/time/108.67780056597796_checkpoint.pth"
test_exp.model.load_state_dict(torch.load(best_model_path))
# Out:
# Use CPU
# load the data  CMAPSSData/   FD001
# test : the shape of data_X is :  (96, 40, 15)
# build not late
# <All keys matched successfully>

# %%
test_exp.model.eval()
prediction = []
gt = []
for data in test_exp.test_loader:
    batch_x = data[0].double().to(test_exp.device)
    batch_y = data[1].double().to(test_exp.device)

    if args.output_attention:
        outputs = test_exp.model(batch_x)[0]
    else:
        outputs = test_exp.model(batch_x)

    batch_y = batch_y.detach().cpu().numpy()
    outputs = outputs.detach().cpu().numpy()
    
    gt.append(batch_y)
    prediction.append(outputs)

# %%
import numpy as np
gt = np.array(gt).reshape(-1,args.sequence_length)
prediction = np.array(prediction).reshape(-1,args.sequence_length)
from sklearn.metrics import mean_squared_error
print(np.sqrt(mean_squared_error(prediction,gt)))
print(np.sqrt(mean_squared_error(prediction[:,-1],gt[:,-1])))
# Out:
# 9.239709777368539
# 11.999690211288842

# %%
for i in range(20):
    plt.figure(figsize=(8,4))
    plt.plot(gt[i])
    plt.plot(prediction[i])

# %%
#     def test(self, save_path):
#         test_data, test_loader = self._get_data(flag='test')
#         self.model.eval()
        
#         preds = []
#         trues = []
        
#         for i, (batch_x,batch_y) in enumerate(test_loader):
#             batch_x = batch_x.double().to(self.device)
#             batch_y = batch_y.long().to(self.device)

#             # prediction
#             if self.args.output_attention:
#                 outputs = self.model(batch_x)[0]
#             else:
#                 outputs = self.model(batch_x)

            
#             pred = list(np.argmax(outputs.detach().cpu().numpy(),axis=1))
#             true = list(batch_y.detach().cpu().numpy())
            
#             preds.extend(pred)
#             trues.extend(true)

#         preds = np.array(preds)
#         trues = np.array(trues)


#         # result save
#         path = './logs/'+save_path+'/'
#         if not os.path.exists(path):
#             os.makedirs(path)
			
#         df_metrics = calculate_metrics(trues, preds)
#         with open(path+"test_result.pickle", "wb") as f:
#             pickle.dump(df_metrics, handle, protocol=pickle.HIGHEST_PROTOCOL)
#         return df_metrics
